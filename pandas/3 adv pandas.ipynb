# %%
import pandas as pd

# %%
df = pd.read_csv('raw_data.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#delete col / row temporary

df.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#but not permanent delete
# this is for col

df.drop("PassengerId", axis=1) # axis = 0 row , axis= 1 col
# Out:
#      Unnamed: 0  Survived  Pclass  \
# 0             0         0       3
# 1             1         1       1
# 2             2         1       3
# 3             3         1       1
# 4             4         0       3
# ..          ...       ...     ...
# 886         886         0       2
# 887         887         1       1
# 888         888         0       3
# 889         889         1       1
# 890         890         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 13 columns]

# %%
#  df =df.drop("PassengerId", axis=1) , reassgined , override ho jayegga df var

df.drop("PassengerId", axis=1 , inplace= True) # true is for permanent delete

# %%
df
# Out:
#      Unnamed: 0  Survived  Pclass  \
# 0             0         0       3
# 1             1         1       1
# 2             2         1       3
# 3             3         1       1
# 4             4         0       3
# ..          ...       ...     ...
# 886         886         0       2
# 887         887         1       1
# 888         888         0       3
# 889         889         1       1
# 890         890         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# for row---------- not permanent

df.drop(3)
# Out:
#      Unnamed: 0  Survived  Pclass  \
# 0             0         0       3
# 1             1         1       1
# 2             2         1       3
# 4             4         0       3
# 5             5         0       3
# ..          ...       ...     ...
# 886         886         0       2
# 887         887         1       1
# 888         888         0       3
# 889         889         1       1
# 890         890         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 4        0            373450   8.0500   NaN        S
# 5        0            330877   8.4583   NaN        Q
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [890 rows x 12 columns]

# %%
df.drop(3 , inplace=True)
df
# Out:
#      Unnamed: 0  Survived  Pclass  \
# 0             0         0       3
# 1             1         1       1
# 2             2         1       3
# 4             4         0       3
# 5             5         0       3
# ..          ...       ...     ...
# 886         886         0       2
# 887         887         1       1
# 888         888         0       3
# 889         889         1       1
# 890         890         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 4        0            373450   8.0500   NaN        S
# 5        0            330877   8.4583   NaN        Q
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [890 rows x 12 columns]

# %%
df
# Out:
#      Unnamed: 0  Survived  Pclass  \
# 0             0         0       3
# 1             1         1       1
# 2             2         1       3
# 4             4         0       3
# 5             5         0       3
# ..          ...       ...     ...
# 886         886         0       2
# 887         887         1       1
# 888         888         0       3
# 889         889         1       1
# 890         890         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 4        0            373450   8.0500   NaN        S
# 5        0            330877   8.4583   NaN        Q
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [890 rows x 12 columns]

# %%
#-----------------------col become index

df.set_index("Name") #but not permanent change
# Out:
#                                                     Unnamed: 0  Survived  \
# Name
# Braund, Mr. Owen Harris                                      0         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...           1         1
# Heikkinen, Miss. Laina                                       2         1
# Allen, Mr. William Henry                                     4         0
# Moran, Mr. James                                             5         0
# ...                                                        ...       ...
# Montvila, Rev. Juozas                                      886         0
# Graham, Miss. Margaret Edith                               887         1
# Johnston, Miss. Catherine Helen "Carrie"                   888         0
# Behr, Mr. Karl Howell                                      889         1
# Dooley, Mr. Patrick                                        890         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
# ...                                                    ...     ...   ...
# Montvila, Rev. Juozas                                    2    male  27.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"                 3  female   NaN
# Behr, Mr. Karl Howell                                    1    male  26.0
# Dooley, Mr. Patrick                                      3    male  32.0
#
#                                                     SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                                 1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# Heikkinen, Miss. Laina                                  0      0
# Allen, Mr. William Henry                                0      0
# Moran, Mr. James                                        0      0
# ...                                                   ...    ...
# Montvila, Rev. Juozas                                   0      0
# Graham, Miss. Margaret Edith                            0      0
# Johnston, Miss. Catherine Helen "Carrie"                1      2
# Behr, Mr. Karl Howell                                   0      0
# Dooley, Mr. Patrick                                     0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Allen, Mr. William Henry                                      373450   8.0500
# Moran, Mr. James                                              330877   8.4583
# ...                                                              ...      ...
# Montvila, Rev. Juozas                                         211536  13.0000
# Graham, Miss. Margaret Edith                                  112053  30.0000
# Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607  23.4500
# Behr, Mr. Karl Howell                                         111369  30.0000
# Dooley, Mr. Patrick                                           370376   7.7500
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Allen, Mr. William Henry                             NaN        S
# Moran, Mr. James                                     NaN        Q
# ...                                                  ...      ...
# Montvila, Rev. Juozas                                NaN        S
# Graham, Miss. Margaret Edith                         B42        S
# Johnston, Miss. Catherine Helen "Carrie"             NaN        S
# Behr, Mr. Karl Howell                               C148        C
# Dooley, Mr. Patrick                                  NaN        Q
#
# [890 rows x 11 columns]

# %%
df.set_index("Name" ,inplace=True) #permanent change into index
df
# Out:
#                                                     Unnamed: 0  Survived  \
# Name
# Braund, Mr. Owen Harris                                      0         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...           1         1
# Heikkinen, Miss. Laina                                       2         1
# Allen, Mr. William Henry                                     4         0
# Moran, Mr. James                                             5         0
# ...                                                        ...       ...
# Montvila, Rev. Juozas                                      886         0
# Graham, Miss. Margaret Edith                               887         1
# Johnston, Miss. Catherine Helen "Carrie"                   888         0
# Behr, Mr. Karl Howell                                      889         1
# Dooley, Mr. Patrick                                        890         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
# ...                                                    ...     ...   ...
# Montvila, Rev. Juozas                                    2    male  27.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"                 3  female   NaN
# Behr, Mr. Karl Howell                                    1    male  26.0
# Dooley, Mr. Patrick                                      3    male  32.0
#
#                                                     SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                                 1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# Heikkinen, Miss. Laina                                  0      0
# Allen, Mr. William Henry                                0      0
# Moran, Mr. James                                        0      0
# ...                                                   ...    ...
# Montvila, Rev. Juozas                                   0      0
# Graham, Miss. Margaret Edith                            0      0
# Johnston, Miss. Catherine Helen "Carrie"                1      2
# Behr, Mr. Karl Howell                                   0      0
# Dooley, Mr. Patrick                                     0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Allen, Mr. William Henry                                      373450   8.0500
# Moran, Mr. James                                              330877   8.4583
# ...                                                              ...      ...
# Montvila, Rev. Juozas                                         211536  13.0000
# Graham, Miss. Margaret Edith                                  112053  30.0000
# Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607  23.4500
# Behr, Mr. Karl Howell                                         111369  30.0000
# Dooley, Mr. Patrick                                           370376   7.7500
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Allen, Mr. William Henry                             NaN        S
# Moran, Mr. James                                     NaN        Q
# ...                                                  ...      ...
# Montvila, Rev. Juozas                                NaN        S
# Graham, Miss. Margaret Edith                         B42        S
# Johnston, Miss. Catherine Helen "Carrie"             NaN        S
# Behr, Mr. Karl Howell                               C148        C
# Dooley, Mr. Patrick                                  NaN        Q
#
# [890 rows x 11 columns]

# %%
df.reset_index()
# Out:
#                                                   Name  Unnamed: 0  Survived  \
# 0                              Braund, Mr. Owen Harris           0         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...           1         1
# 2                               Heikkinen, Miss. Laina           2         1
# 3                             Allen, Mr. William Henry           4         0
# 4                                     Moran, Mr. James           5         0
# ..                                                 ...         ...       ...
# 885                              Montvila, Rev. Juozas         886         0
# 886                       Graham, Miss. Margaret Edith         887         1
# 887           Johnston, Miss. Catherine Helen "Carrie"         888         0
# 888                              Behr, Mr. Karl Howell         889         1
# 889                                Dooley, Mr. Patrick         890         0
#
#      Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1         1  female  38.0      1      0          PC 17599  71.2833   C85
# 2         3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3         3    male  35.0      0      0            373450   8.0500   NaN
# 4         3    male   NaN      0      0            330877   8.4583   NaN
# ..      ...     ...   ...    ...    ...               ...      ...   ...
# 885       2    male  27.0      0      0            211536  13.0000   NaN
# 886       1  female  19.0      0      0            112053  30.0000   B42
# 887       3  female   NaN      1      2        W./C. 6607  23.4500   NaN
# 888       1    male  26.0      0      0            111369  30.0000  C148
# 889       3    male  32.0      0      0            370376   7.7500   NaN
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          Q
# ..       ...
# 885        S
# 886        S
# 887        S
# 888        C
# 889        Q
#
# [890 rows x 12 columns]

# %%
#-----------------convert dict into dataframe

d = { 'key1':[3,4,5,6,7],
     'key2':[5,6,7,8,6],    #but all arr must same len  key2':[5,6,7,8]
     'key3':[4,5,6,7,8]
}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     3     5     4
# 1     4     6     5
# 2     5     7     6
# 3     6     8     7
# 4     7     6     8

# %%
df1 = pd.read_csv('taxonomy.csv.xls')
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
#-----------------remove nan record but not permanent . inplace

df1.dropna(inplace=True)  #delete row bydefault bcuz axis 0

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1.dropna(axis=1)
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df2= pd.read_csv('taxonomy.csv.xls')
df2
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
# remove entire col where nan value exist

df2.dropna(axis=1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
# ----fill nan value with sufeeya or other name

df2.fillna('sufeeya')
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency   sufeeya               sufeeya
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df
# Out:
#                                                     Unnamed: 0  Survived  \
# Name
# Braund, Mr. Owen Harris                                      0         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...           1         1
# Heikkinen, Miss. Laina                                       2         1
# Allen, Mr. William Henry                                     4         0
# Moran, Mr. James                                             5         0
# ...                                                        ...       ...
# Montvila, Rev. Juozas                                      886         0
# Graham, Miss. Margaret Edith                               887         1
# Johnston, Miss. Catherine Helen "Carrie"                   888         0
# Behr, Mr. Karl Howell                                      889         1
# Dooley, Mr. Patrick                                        890         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
# ...                                                    ...     ...   ...
# Montvila, Rev. Juozas                                    2    male  27.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"                 3  female   NaN
# Behr, Mr. Karl Howell                                    1    male  26.0
# Dooley, Mr. Patrick                                      3    male  32.0
#
#                                                     SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                                 1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# Heikkinen, Miss. Laina                                  0      0
# Allen, Mr. William Henry                                0      0
# Moran, Mr. James                                        0      0
# ...                                                   ...    ...
# Montvila, Rev. Juozas                                   0      0
# Graham, Miss. Margaret Edith                            0      0
# Johnston, Miss. Catherine Helen "Carrie"                1      2
# Behr, Mr. Karl Howell                                   0      0
# Dooley, Mr. Patrick                                     0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Allen, Mr. William Henry                                      373450   8.0500
# Moran, Mr. James                                              330877   8.4583
# ...                                                              ...      ...
# Montvila, Rev. Juozas                                         211536  13.0000
# Graham, Miss. Margaret Edith                                  112053  30.0000
# Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607  23.4500
# Behr, Mr. Karl Howell                                         111369  30.0000
# Dooley, Mr. Patrick                                           370376   7.7500
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Allen, Mr. William Henry                             NaN        S
# Moran, Mr. James                                     NaN        Q
# ...                                                  ...      ...
# Montvila, Rev. Juozas                                NaN        S
# Graham, Miss. Margaret Edith                         B42        S
# Johnston, Miss. Catherine Helen "Carrie"             NaN        S
# Behr, Mr. Karl Howell                               C148        C
# Dooley, Mr. Patrick                                  NaN        Q
#
# [890 rows x 11 columns]

# %%
df.reset_index(inplace=True)
df
# Out:
#      index                                               Name  Unnamed: 0  \
# 0        0                            Braund, Mr. Owen Harris           0
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...           1
# 2        2                             Heikkinen, Miss. Laina           2
# 3        3                           Allen, Mr. William Henry           4
# 4        4                                   Moran, Mr. James           5
# ..     ...                                                ...         ...
# 885    885                              Montvila, Rev. Juozas         886
# 886    886                       Graham, Miss. Margaret Edith         887
# 887    887           Johnston, Miss. Catherine Helen "Carrie"         888
# 888    888                              Behr, Mr. Karl Howell         889
# 889    889                                Dooley, Mr. Patrick         890
#
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           0       3    male  35.0      0      0            373450   8.0500
# 4           0       3    male   NaN      0      0            330877   8.4583
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 885         0       2    male  27.0      0      0            211536  13.0000
# 886         1       1  female  19.0      0      0            112053  30.0000
# 887         0       3  female   NaN      1      2        W./C. 6607  23.4500
# 888         1       1    male  26.0      0      0            111369  30.0000
# 889         0       3    male  32.0      0      0            370376   7.7500
#
#     Cabin Embarked
# 0     NaN        S
# 1     C85        C
# 2     NaN        S
# 3     NaN        S
# 4     NaN        Q
# ..    ...      ...
# 885   NaN        S
# 886   B42        S
# 887   NaN        S
# 888  C148        C
# 889   NaN        Q
#
# [890 rows x 13 columns]

# %%
#----groupby operation

g = df.groupby('Survived' )
g

# %%
g.sum()
# Out:
# /tmp/ipykernel_822/1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#            index  Unnamed: 0  Pclass       Age  SibSp  Parch        Fare
# Survived
# 0         244315      244863    1390  12985.50    304    181  12142.7199
# 1         151290      151629     666   8184.67    161    159  16498.1294

# %%
g.mean()#avg
# Out:
# /tmp/ipykernel_822/1279380572.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()#avg
#                index  Unnamed: 0    Pclass        Age     SibSp     Parch  \
# Survived
# 0         445.018215  446.016393  2.531876  30.626179  0.553734  0.329690
# 1         443.665689  444.659824  1.953079  28.320657  0.472141  0.466276
#
#                Fare
# Survived
# 0         22.117887
# 1         48.381611

# %%
p = df.groupby('Pclass')
p

# %%
p.sum()
# Out:
# /tmp/ipykernel_822/943096461.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   p.sum()
#          index  Unnamed: 0  Survived      Age  SibSp  Parch        Fare
# Pclass
# 1        99272       99486       135  7076.42     89     77  18124.3125
# 2        81688       81872        87  5168.83     74     70   3801.8417
# 3       214645      215134       119  8924.92    302    193   6714.6951

# %%
p.mean()
# Out:
# /tmp/ipykernel_822/288629575.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   p.mean()
#              index  Unnamed: 0  Survived        Age     SibSp     Parch  \
# Pclass
# 1       461.730233  462.725581  0.627907  38.250919  0.413953  0.358140
# 2       443.956522  444.956522  0.472826  29.877630  0.402174  0.380435
# 3       437.158859  438.154786  0.242363  25.140620  0.615071  0.393075
#
#              Fare
# Pclass
# 1       84.299128
# 2       20.662183
# 3       13.675550

# %%
#-----------p.max().transepose
p.max().T # transpose data- is for col to row , row to col
# Out:
# /tmp/ipykernel_822/1665691157.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   p.max().T
# Pclass                             1                          2  \
# index                            888                        885
# Name        Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Unnamed: 0                       889                        886
# Survived                           1                          1
# Sex                             male                       male
# Age                             80.0                       70.0
# SibSp                              3                          3
# Parch                              4                          3
# Ticket                     WE/P 5735                  W/C 14208
# Fare                        512.3292                       73.5
#
# Pclass                                3
# index                               889
# Name        van Melkebeke, Mr. Philemon
# Unnamed: 0                          890
# Survived                              1
# Sex                                male
# Age                                74.0
# SibSp                                 8
# Parch                                 6
# Ticket                       W./C. 6609
# Fare                              69.55

# %%
p.max()["Fare"]
# Out:
# /tmp/ipykernel_822/1260380138.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   p.max()["Fare"]
# Pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: Fare, dtype: float64

# %%
df
# Out:
#      index                                               Name  Unnamed: 0  \
# 0        0                            Braund, Mr. Owen Harris           0
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...           1
# 2        2                             Heikkinen, Miss. Laina           2
# 3        3                           Allen, Mr. William Henry           4
# 4        4                                   Moran, Mr. James           5
# ..     ...                                                ...         ...
# 885    885                              Montvila, Rev. Juozas         886
# 886    886                       Graham, Miss. Margaret Edith         887
# 887    887           Johnston, Miss. Catherine Helen "Carrie"         888
# 888    888                              Behr, Mr. Karl Howell         889
# 889    889                                Dooley, Mr. Patrick         890
#
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           0       3    male  35.0      0      0            373450   8.0500
# 4           0       3    male   NaN      0      0            330877   8.4583
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 885         0       2    male  27.0      0      0            211536  13.0000
# 886         1       1  female  19.0      0      0            112053  30.0000
# 887         0       3  female   NaN      1      2        W./C. 6607  23.4500
# 888         1       1    male  26.0      0      0            111369  30.0000
# 889         0       3    male  32.0      0      0            370376   7.7500
#
#     Cabin Embarked
# 0     NaN        S
# 1     C85        C
# 2     NaN        S
# 3     NaN        S
# 4     NaN        Q
# ..    ...      ...
# 885   NaN        S
# 886   B42        S
# 887   NaN        S
# 888  C148        C
# 889   NaN        Q
#
# [890 rows x 13 columns]

# %%
#------------subset of data

df5 = df[[ 'Name', 'Survived' , 'Pclass']][0:5]
df5
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3

# %%
df6 = df[[ 'Name', 'Survived' , 'Pclass']][5:10]
df6
# Out:
#                                                 Name  Survived  Pclass
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
#------concatenation df5 df6 vertically , horizontaly

pd.concat([df5,df6])
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
df7 = pd.concat([df5,df6] , axis=1) # by col wise show horizontal
df7
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris       0.0     3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1.0     1.0
# 2                             Heikkinen, Miss. Laina       1.0     3.0
# 3                           Allen, Mr. William Henry       0.0     3.0
# 4                                   Moran, Mr. James       0.0     3.0
# 5                                                NaN       NaN     NaN
# 6                                                NaN       NaN     NaN
# 7                                                NaN       NaN     NaN
# 8                                                NaN       NaN     NaN
# 9                                                NaN       NaN     NaN
#
#                                                 Name  Survived  Pclass
# 0                                                NaN       NaN     NaN
# 1                                                NaN       NaN     NaN
# 2                                                NaN       NaN     NaN
# 3                                                NaN       NaN     NaN
# 4                                                NaN       NaN     NaN
# 5                            McCarthy, Mr. Timothy J       0.0     1.0
# 6                     Palsson, Master. Gosta Leonard       0.0     3.0
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       1.0     3.0
# 8                Nasser, Mrs. Nicholas (Adele Achem)       1.0     2.0
# 9                    Sandstrom, Miss. Marguerite Rut       1.0     3.0

# %%
df7.fillna("abc")
# Out:
#                                                 Name Survived Pclass  \
# 0                            Braund, Mr. Owen Harris      0.0    3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1.0    1.0
# 2                             Heikkinen, Miss. Laina      1.0    3.0
# 3                           Allen, Mr. William Henry      0.0    3.0
# 4                                   Moran, Mr. James      0.0    3.0
# 5                                                abc      abc    abc
# 6                                                abc      abc    abc
# 7                                                abc      abc    abc
# 8                                                abc      abc    abc
# 9                                                abc      abc    abc
#
#                                                 Name Survived Pclass
# 0                                                abc      abc    abc
# 1                                                abc      abc    abc
# 2                                                abc      abc    abc
# 3                                                abc      abc    abc
# 4                                                abc      abc    abc
# 5                            McCarthy, Mr. Timothy J      0.0    1.0
# 6                     Palsson, Master. Gosta Leonard      0.0    3.0
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      1.0    3.0
# 8                Nasser, Mrs. Nicholas (Adele Achem)      1.0    2.0
# 9                    Sandstrom, Miss. Marguerite Rut      1.0    3.0

# %%
data1= pd.DataFrame({ 'key1': [1,2,3,4,6],
                      'key2': [4,5,6,7,8],
                      'key3':[3,4,5,6,6]
})
data1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     3     6     5
# 3     4     7     6
# 4     6     8     6

# %%
data2= pd.DataFrame({ 'key1': [1,2,3,45,67],
                      'key4': [56,5,6,7,8],
                      'key5':[3,56,5,6,6]
                    })                    
data2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2     3     6     5
# 3    45     7     6
# 4    67     8     6

# %%
# ----------------merge data like venn digram , take common from col, column ko dekh kr work krta h

pd.merge(data1, data2 , how ="left" , on="key1")
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3  56.0   3.0
# 1     2     5     4   5.0  56.0
# 2     3     6     5   6.0   5.0
# 3     4     7     6   NaN   NaN
# 4     6     8     6   NaN   NaN

# %%
data1= pd.DataFrame({ 'key1': [1,2,3,4,6],
                      'key2': [4,5,6,7,8],
                      'key3':[3,4,5,6,6]},
                   index=['a', 'b','c', 'd', 'e']
)

# %%
data2= pd.DataFrame({ 'key11': [1,2,3,4,6],
                      'key22': [4,5,6,7,8],
                      'key33':[3,4,5,6,6]},
                     index=['a', 'b','h', 'i', 'j']
                    
)

# %%
#---------join

data1
# Out:
#    key1  key2  key3
# a     1     4     3
# b     2     5     4
# c     3     6     5
# d     4     7     6
# e     6     8     6

# %%
data2
# Out:
#    key11  key22  key33
# a      1      4      3
# b      2      5      4
# h      3      6      5
# i      4      7      6
# j      6      8      6

# %%
data1.join(data2)  #from left,,, join same sa merge , but index se common work krta
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     3    1.0    4.0    3.0
# b     2     5     4    2.0    5.0    4.0
# c     3     6     5    NaN    NaN    NaN
# d     4     7     6    NaN    NaN    NaN
# e     6     8     6    NaN    NaN    NaN

# %%
df
# Out:
#      index                                               Name  Unnamed: 0  \
# 0        0                            Braund, Mr. Owen Harris           0
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...           1
# 2        2                             Heikkinen, Miss. Laina           2
# 3        3                           Allen, Mr. William Henry           4
# 4        4                                   Moran, Mr. James           5
# ..     ...                                                ...         ...
# 885    885                              Montvila, Rev. Juozas         886
# 886    886                       Graham, Miss. Margaret Edith         887
# 887    887           Johnston, Miss. Catherine Helen "Carrie"         888
# 888    888                              Behr, Mr. Karl Howell         889
# 889    889                                Dooley, Mr. Patrick         890
#
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           0       3    male  35.0      0      0            373450   8.0500
# 4           0       3    male   NaN      0      0            330877   8.4583
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 885         0       2    male  27.0      0      0            211536  13.0000
# 886         1       1  female  19.0      0      0            112053  30.0000
# 887         0       3  female   NaN      1      2        W./C. 6607  23.4500
# 888         1       1    male  26.0      0      0            111369  30.0000
# 889         0       3    male  32.0      0      0            370376   7.7500
#
#     Cabin Embarked
# 0     NaN        S
# 1     C85        C
# 2     NaN        S
# 3     NaN        S
# 4     NaN        Q
# ..    ...      ...
# 885   NaN        S
# 886   B42        S
# 887   NaN        S
# 888  C148        C
# 889   NaN        Q
#
# [890 rows x 13 columns]

# %%
# ------convert uro into rs ,then new col fare in inr
# apply fun work on entire col

df['Fare_Inr']= df["Fare"].apply(lambda x:x*80)

# %%
df.head()
# Out:
#    index                                               Name  Unnamed: 0  \
# 0      0                            Braund, Mr. Owen Harris           0
# 1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...           1
# 2      2                             Heikkinen, Miss. Laina           2
# 3      3                           Allen, Mr. William Henry           4
# 4      4                                   Moran, Mr. James           5
#
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         0       3    male  35.0      0      0            373450   8.0500
# 4         0       3    male   NaN      0      0            330877   8.4583
#
#   Cabin Embarked  Fare_Inr
# 0   NaN        S   580.000
# 1   C85        C  5702.664
# 2   NaN        S   634.000
# 3   NaN        S   644.000
# 4   NaN        Q   676.664

# %%
df["Name_len"]= df['Name'].apply(len)

# %%
df.head()
# Out:
#    index                                               Name  Unnamed: 0  \
# 0      0                            Braund, Mr. Owen Harris           0
# 1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...           1
# 2      2                             Heikkinen, Miss. Laina           2
# 3      3                           Allen, Mr. William Henry           4
# 4      4                                   Moran, Mr. James           5
#
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         0       3    male  35.0      0      0            373450   8.0500
# 4         0       3    male   NaN      0      0            330877   8.4583
#
#   Cabin Embarked  Fare_Inr  Name_len
# 0   NaN        S   580.000        23
# 1   C85        C  5702.664        51
# 2   NaN        S   634.000        22
# 3   NaN        S   644.000        24
# 4   NaN        Q   676.664        16

# %%
def cat_fare(x):
    if x<10:
         return"cheap"
    elif x>=10 and x<20:
        return 'mid'
    else :
         return 'high'
        
df['cat_fare'] = df['Fare'].apply(cat_fare)
df
# Out:
#      index                                               Name  Unnamed: 0  \
# 0        0                            Braund, Mr. Owen Harris           0
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...           1
# 2        2                             Heikkinen, Miss. Laina           2
# 3        3                           Allen, Mr. William Henry           4
# 4        4                                   Moran, Mr. James           5
# ..     ...                                                ...         ...
# 885    885                              Montvila, Rev. Juozas         886
# 886    886                       Graham, Miss. Margaret Edith         887
# 887    887           Johnston, Miss. Catherine Helen "Carrie"         888
# 888    888                              Behr, Mr. Karl Howell         889
# 889    889                                Dooley, Mr. Patrick         890
#
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           0       3    male  35.0      0      0            373450   8.0500
# 4           0       3    male   NaN      0      0            330877   8.4583
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 885         0       2    male  27.0      0      0            211536  13.0000
# 886         1       1  female  19.0      0      0            112053  30.0000
# 887         0       3  female   NaN      1      2        W./C. 6607  23.4500
# 888         1       1    male  26.0      0      0            111369  30.0000
# 889         0       3    male  32.0      0      0            370376   7.7500
#
#     Cabin Embarked  Fare_Inr  Name_len cat_fare
# 0     NaN        S   580.000        23    cheap
# 1     C85        C  5702.664        51     high
# 2     NaN        S   634.000        22    cheap
# 3     NaN        S   644.000        24    cheap
# 4     NaN        Q   676.664        16    cheap
# ..    ...      ...       ...       ...      ...
# 885   NaN        S  1040.000        21      mid
# 886   B42        S  2400.000        28     high
# 887   NaN        S  1876.000        40     high
# 888  C148        C  2400.000        21     high
# 889   NaN        Q   620.000        19    cheap
#
# [890 rows x 16 columns]
